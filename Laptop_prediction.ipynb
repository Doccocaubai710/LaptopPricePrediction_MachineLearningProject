# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
image = mpimg.imread('Laptop.png')
plt.imshow(image)
plt.axis('off')  # Tắt hiển thị trục
plt.show()

# %%
#Import libraries and dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df=pd.read_csv('laptop_data.csv')
df.head(5)
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %% [markdown]
# BASIC UNDERSTANDING FOR DATA

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
#Drop unrequired column
df.drop(columns='Unnamed: 0',inplace=True)
df.head(5)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
#NOW SPLIT the mixed variables
df['Ram'] = df['Ram'].str.replace('GB','')

#Weight---
df['Weight'] = df['Weight'].str.replace('kg','')

#Change data type----
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')
df.sample(5)
# Out:
#      Company            TypeName  Inches             ScreenResolution  \
# 1064     MSI              Gaming    15.6            Full HD 1920x1080
# 592     Dell  2 in 1 Convertible    11.6         Touchscreen 1366x768
# 1172    Asus            Notebook    15.6                     1366x768
# 85      Dell              Gaming    15.6  IPS Panel Full HD 1920x1080
# 1195      HP            Notebook    15.6  IPS Panel Full HD 1920x1080
#
#                                        Cpu  Ram                Memory  \
# 1064           Intel Core i7 6700HQ 2.6GHz   16  256GB SSD +  1TB HDD
# 592               Intel Core M 7Y30 1.0GHz    4             128GB SSD
# 1172  Intel Celeron Dual Core N3050 1.6GHz    4             500GB HDD
# 85             Intel Core i7 7700HQ 2.8GHz   16  128GB SSD +  1TB HDD
# 1195           Intel Core i7 7700HQ 2.8GHz   12  128GB SSD +  1TB HDD
#
#                              Gpu       OpSys  Weight      Price
# 1064     Nvidia GeForce GTX 1060  Windows 10    1.80  102777.12
# 592        Intel HD Graphics 615  Windows 10    1.39   32127.84
# 1172           Intel HD Graphics  Windows 10    2.20   19660.32
# 85    Nvidia GeForce GTX 1050 Ti  Windows 10    2.65   71874.72
# 1195     Nvidia GeForce GTX 1050  Windows 10    2.21   70702.56

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %% [markdown]
# #EDA with Data

# %% [markdown]
# 1.Price distribution

# %%
sns.distplot(df['Price'],hist_kws={'color':'purple','edgecolor':'black','linewidth':.5,'linestyle':'-'})
sns.set(rc={'figure.figsize':(7,5)})
plt.title('Price distribution')
plt.show()
# Out:
# C:\Users\MinhHoang\AppData\Local\Temp\ipykernel_3432\415629328.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'],hist_kws={'color':'purple','edgecolor':'black','linewidth':.5,'linestyle':'-'})

# %% [markdown]
# 2.Company

# %%
#Company wise laptop------
sns.countplot(x='Company',data=df,palette='PiYG')
plt.xticks(rotation='vertical')
plt.title("Company wise laptop")
sns.set(rc={"figure.figsize":(8, 8)})
plt.show()

#Company with Price------
sns.barplot(x='Company',y='Price',data=df,palette='PiYG')
plt.xticks(rotation='vertical')
sns.set(rc={'figure.figsize':(7,7)})
plt.title('Company wise Price')
plt.show()

# %% [markdown]
# 3.TypeName

# %%
#Type name wise laptops-----
sns.countplot(x="TypeName",data=df,palette='PiYG')
plt.xticks(rotation='vertical')
plt.title("TypeName wise laptops")
sns.set(rc={'figure.figsize':(8,8)})
plt.show()

#TypeName wise Price--------
sns.barplot(x='TypeName',y='Price',data=df,palette='PiYG')
plt.xticks(rotation='vertical')
plt.title("TypeName wise Price")
sns.set(rc={'figure.figsize':(7,7)})
plt.show()

# %% [markdown]
# 4.Inches

# %%
#Distplot 
sns.distplot(df['Inches'],hist_kws={'color':'red','edgecolor':'black','linewidth':.5,
                                   'linestyle':'--'})
sns.set(rc={'figure.figsize':(7,5)})
plt.title('Inches')
plt.show()

#Scatter plot------
sns.scatterplot(x='Inches',y='Price',hue='Inches',marker='+',data=df)
plt.title('Inches with price')
sns.set(rc={'figure.figsize':(8,8)})
plt.show()
# Out:
# C:\Users\MinhHoang\AppData\Local\Temp\ipykernel_3432\3358653546.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Inches'],hist_kws={'color':'red','edgecolor':'black','linewidth':.5,

# %% [markdown]
# 5. Work with screen resolution

# %%
print(df['ScreenResolution'].value_counts())
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ 2560x1440                       3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# Touchscreen 2400x1600                              3
# 2560x1440                                          3
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 1920x1200                        1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: ScreenResolution, dtype: int64

# %%
#Split the column based on Touchscreen
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)
df['Ips'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)
df.sample(10)
# Out:
#       Company            TypeName  Inches  \
# 356    Lenovo            Notebook    15.6
# 546    Lenovo            Notebook    14.0
# 1003       HP            Notebook    14.0
# 1298   Lenovo  2 in 1 Convertible    14.0
# 715    Lenovo            Notebook    14.0
# 655   Toshiba            Notebook    15.6
# 36       Acer            Notebook    15.6
# 148       MSI              Gaming    17.3
# 109    Lenovo            Notebook    14.0
# 274   Toshiba            Notebook    15.6
#
#                                ScreenResolution  \
# 356                                    1366x768
# 546                           Full HD 1920x1080
# 1003                                   1366x768
# 1298  IPS Panel Full HD / Touchscreen 1920x1080
# 715                 IPS Panel Full HD 1920x1080
# 655                 IPS Panel Full HD 1920x1080
# 36                                     1366x768
# 148                           Full HD 1920x1080
# 109                 IPS Panel Full HD 1920x1080
# 274                                    1366x768
#
#                                        Cpu  Ram                Memory  \
# 356   Intel Celeron Dual Core N3350 1.1GHz    4               1TB HDD
# 546             Intel Core i5 7200U 2.5GHz    4             500GB HDD
# 1003            Intel Core i5 7200U 2.5GHz    4             500GB HDD
# 1298            Intel Core i7 6500U 2.5GHz    4             128GB SSD
# 715             Intel Core i5 7200U 2.5GHz    8             256GB SSD
# 655             Intel Core i5 7200U 2.5GHz    8             500GB HDD
# 36              Intel Core i3 7130U 2.7GHz    4               1TB HDD
# 148            Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
# 109             Intel Core i7 7500U 2.7GHz    8             256GB SSD
# 274             Intel Core i7 6500U 2.5GHz    8             500GB HDD
#
#                           Gpu       OpSys  Weight        Price  Touchscreen  \
# 356     Intel HD Graphics 500       No OS    2.20   17155.6272            0
# 546     Intel HD Graphics 620  Windows 10    1.87   41824.8000            0
# 1003    Intel HD Graphics 620  Windows 10    1.64   41505.1200            0
# 1298    Intel HD Graphics 520  Windows 10    1.80   33992.6400            1
# 715      Nvidia GeForce 920MX  Windows 10    1.87   45664.6896            0
# 655     Intel HD Graphics 620  Windows 10    2.00   56689.9200            0
# 36      Intel HD Graphics 620       Linux    2.10   19553.7600            0
# 148   Nvidia GeForce GTX 1070  Windows 10    2.90  108105.1200            0
# 109     Intel HD Graphics 620  Windows 10    1.58   78854.4000            0
# 274       Nvidia GeForce 930M  Windows 10    2.20   43263.3600            0
#
#       Ips
# 356     0
# 546     0
# 1003    0
# 1298    1
# 715     1
# 655     1
# 36      0
# 148     0
# 109     1
# 274     0

# %%
#Touchscreen
sns.countplot(x="Touchscreen",data=df,palette='PiYG')
plt.title('Count Touchscreen')
plt.xticks(rotation='vertical')
sns.set(rc={'figure.figsize':(5,5)})
plt.show()

sns.barplot(x='Touchscreen',y='Price',data=df,palette='PiYG')
plt.title('TouchScreen with Price')
plt.xticks(rotation='vertical')
sns.set(rc={'figure.figsize':(5,5)})
plt.show()

# %%
#IPs
sns.countplot(x='Ips',data=df,palette='PiYG')
plt.xticks(rotation='vertical')
plt.title('Count IPs')
sns.set(rc={'figure.figsize':(5,5)})
plt.show()

#TypeName with Price
sns.barplot(x='Ips',y='Price',data=df,palette='PiYG')
plt.xticks(rotation='vertical')
sns.set(rc={'figure.figsize':(5,5)})
plt.title('IPs with Price')
plt.show()

# %%
new=df['ScreenResolution'].str.split('x',n=1,expand=True)
#Again split the screen resolution
df['X_res']=new[0]
df['Y-res']=new[1]
df.sample(5)
# Out:
#       Company   TypeName  Inches             ScreenResolution  \
# 983   Fujitsu   Notebook    15.6                     1366x768
# 1301       HP   Notebook    15.6                     1366x768
# 114      Dell  Ultrabook    13.3  IPS Panel Full HD 1920x1080
# 264      Dell   Notebook    15.6            Full HD 1920x1080
# 199        HP   Notebook    17.3            Full HD 1920x1080
#
#                              Cpu  Ram     Memory                     Gpu  \
# 983   Intel Core i5 6200U 2.3GHz    4  256GB SSD   Intel HD Graphics 520
# 1301  Intel Core i7 6500U 2.5GHz    6    1TB HDD      AMD Radeon R5 M330
# 114   Intel Core i5 8250U 1.6GHz    8  256GB SSD  Intel UHD Graphics 620
# 264   Intel Core i5 7200U 2.5GHz    8    1TB HDD      AMD Radeon R5 M430
# 199   Intel Core i7 8550U 1.8GHz    8  256GB SSD   Nvidia GeForce 930MX
#
#            OpSys  Weight     Price  Touchscreen  Ips                   X_res  \
# 983   Windows 10    2.30  34578.72            0    0                    1366
# 1301  Windows 10    2.19  40705.92            0    0                    1366
# 114   Windows 10    1.21  86793.12            0    1  IPS Panel Full HD 1920
# 264   Windows 10    2.24  30103.20            0    0            Full HD 1920
# 199   Windows 10    2.50  55677.60            0    0            Full HD 1920
#
#      Y-res
# 983    768
# 1301   768
# 114   1080
# 264   1080
# 199   1080

# %%
#Edit X-res
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])
df.sample(5)
# Out:
#      Company            TypeName  Inches  \
# 1294      HP            Notebook    15.6
# 1081  Lenovo              Gaming    17.3
# 886     Dell            Notebook    15.6
# 50    Lenovo  2 in 1 Convertible    10.1
# 755   Lenovo  2 in 1 Convertible    13.3
#
#                                 ScreenResolution                          Cpu  \
# 1294                           Full HD 1920x1080    AMD A9-Series 9410 2.9GHz
# 1081                 IPS Panel Full HD 1920x1080  Intel Core i7 6820HK 2.7GHz
# 886                                     1366x768   Intel Core i3 6006U 2.0GHz
# 50               IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz
# 755   IPS Panel Quad HD+ / Touchscreen 3200x1800   Intel Core i5 6260U 1.8GHz
#
#       Ram                     Memory                      Gpu       OpSys  \
# 1294    6               1.0TB Hybrid       AMD Radeon R7 M440  Windows 10
# 1081   32  512GB SSD +  1.0TB Hybrid  Nvidia GeForce GTX 980M  Windows 10
# 886     4                    1TB HDD      AMD Radeon R5 M420X       Linux
# 50      4         64GB Flash Storage    Intel HD Graphics 400     Android
# 755     8                  256GB SSD    Intel HD Graphics 540  Windows 10
#
#       Weight        Price  Touchscreen  Ips X_res Y-res
# 1294    2.04   29303.4672            0    0  1920  1080
# 1081    4.60  172627.2000            0    1  1920  1080
# 886     2.18   24279.6960            0    0  1366   768
# 50      0.69   16996.3200            1    1  1920  1200
# 755     1.30   63882.7200            1    1  3200  1800

# %%
#Change datatype
df['X_res']=df['X_res'].astype('int')
df['Y-res']=df['Y-res'].astype('int')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y-res             1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# memory usage: 132.5+ KB

# %% [markdown]
# #WORK WITH PRICE

# %%
df.corr()['Price']
# Out:
# C:\Users\MinhHoang\AppData\Local\Temp\ipykernel_3432\815546952.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price']
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# X_res          0.556529
# Y-res          0.552809
# Name: Price, dtype: float64

# %%
df['ppi']=((df['X_res']**2+df['Y-res']**2)**0.5/df['Inches']).astype(float)
df.corr()['Price']
# Out:
# C:\Users\MinhHoang\AppData\Local\Temp\ipykernel_3432\3000508125.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price']
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# X_res          0.556529
# Y-res          0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %%
df.sample(5)
# Out:
#     Company            TypeName  Inches  \
# 946    Dell           Ultrabook    12.5
# 244  Lenovo  2 in 1 Convertible    13.9
# 25     Dell            Notebook    15.6
# 326    Acer            Notebook    15.6
# 791    Vero            Notebook    14.0
#
#                               ScreenResolution  \
# 946            Full HD / Touchscreen 1920x1080
# 244  IPS Panel Full HD / Touchscreen 1920x1080
# 25                                    1366x768
# 326                                   1366x768
# 791                                  1920x1080
#
#                                       Cpu  Ram              Memory  \
# 946            Intel Core i5 7200U 2.5GHz    8           256GB SSD
# 244            Intel Core i7 7500U 2.7GHz    8           256GB SSD
# 25               Intel Core i3 6006U 2GHz    4             1TB HDD
# 326            Intel Core i5 7200U 2.5GHz    6             1TB HDD
# 791  Intel Celeron Dual Core N3350 1.1GHz    4  32GB Flash Storage
#
#                        Gpu       OpSys  Weight       Price  Touchscreen  Ips  \
# 946      Intel HD Graphics  Windows 10    1.36  78438.8160            1    0
# 244  Intel HD Graphics 620  Windows 10    1.38  57489.1200            1    1
# 25   Intel HD Graphics 520  Windows 10    2.30  22305.1392            0    0
# 326  Intel HD Graphics 620  Windows 10    2.23  29250.7200            0    0
# 791  Intel HD Graphics 500  Windows 10    1.22  10810.5120            0    0
#
#      X_res  Y-res         ppi
# 946   1920   1080  176.232574
# 244   1920   1080  158.482530
# 25    1366    768  100.454670
# 326   1366    768  100.454670
# 791   1920   1080  157.350512

# %%
df.drop(columns=['ScreenResolution','Inches','X_res','Y-res'],inplace=True)
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi
# 0  226.983005
# 1  127.677940
# 2  141.211998
# 3  220.534624
# 4  226.983005

# %% [markdown]
# WORK WITH CPU

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
#Split first 3 words
df['Cpu Name']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))
df.sample(5)
# Out:
#      Company            TypeName                          Cpu  Ram     Memory  \
# 302   Lenovo            Notebook   Intel Core i5 7200U 2.5GHz    6    1TB HDD
# 771  Samsung  2 in 1 Convertible   Intel Core i7 7500U 2.7GHz   16  256GB SSD
# 614     Dell            Notebook   Intel Core i5 7300U 2.6GHz    4  500GB HDD
# 81     Apple           Ultrabook         Intel Core i5 1.3GHz    8  512GB SSD
# 711     Dell            Notebook  Intel Core i5 7440HQ 2.8GHz    8  256GB SSD
#
#                          Gpu       OpSys  Weight     Price  Touchscreen  Ips  \
# 302  Nvidia GeForce GTX 940M  Windows 10    2.80  34578.72            0    0
# 771           AMD Radeon 540  Windows 10    1.71  95850.72            1    0
# 614    Intel HD Graphics 620       Linux    1.93  46300.32            0    0
# 81     Intel HD Graphics 615       macOS    0.92  80452.80            0    1
# 711     Nvidia GeForce 930MX       Linux    1.64  58021.92            0    0
#
#             ppi       Cpu Name
# 302  106.113062  Intel Core i5
# 771  146.860478  Intel Core i7
# 614  100.454670  Intel Core i5
# 81   226.415547  Intel Core i5
# 711  157.350512  Intel Core i5

# %%
#CPU name extration function
def fetch_processor(text):
    if text=='Intel Core i7' or text=='Intel Core i5' or text=='Intel Core i3':
        return text
    else:
        if text.split()[0]=='Intel':
            return 'Other Intel Processor'
        else: 
            return 'AMD processor'

df['Cpu Branch']=df['Cpu Name'].apply(fetch_processor)
df.sample(5)
# Out:
#      Company   TypeName                          Cpu  Ram  \
# 1283    Asus   Notebook   Intel Core i7 6500U 2.5GHz    4
# 1162      HP     Gaming  Intel Core i7 7700HQ 2.8GHz    8
# 1166  Lenovo   Notebook   Intel Core i5 7200U 2.5GHz    8
# 366     Dell   Notebook   Intel Core i5 8250U 1.6GHz    8
# 24        HP  Ultrabook   Intel Core i7 8550U 1.8GHz    8
#
#                     Memory                      Gpu       OpSys  Weight  \
# 1283             500GB HDD      Nvidia GeForce 920M  Windows 10    2.20
# 1162               1TB HDD  Nvidia GeForce GTX 1050  Windows 10    2.62
# 1166             256GB SSD    Intel HD Graphics 620  Windows 10    1.95
# 366   128GB SSD +  1TB HDD           AMD Radeon 530  Windows 10    2.80
# 24               256GB SSD    Intel HD Graphics 620  Windows 10    1.91
#
#            Price  Touchscreen  Ips         ppi       Cpu Name     Cpu Branch
# 1283  38378.6496            0    0  100.454670  Intel Core i7  Intel Core i7
# 1162  47898.7200            0    1  141.211998  Intel Core i7  Intel Core i7
# 1166  74059.2000            0    1  141.211998  Intel Core i5  Intel Core i5
# 366   57808.8000            0    0  127.335675  Intel Core i5  Intel Core i5
# 24    35111.5200            0    0  141.211998  Intel Core i7  Intel Core i7

# %%
#CPU branch
sns.countplot(x='Cpu Branch',data=df,palette='PiYG')
plt.xticks(rotation='vertical')
plt.title('CPU wise laptop')
sns.set(rc={'figure.figsize':(5,5)})
plt.show()


#CPU Branch wise price
sns.barplot(x='Cpu Branch',y='Price',data=df,palette='PiYG')
plt.xticks(rotation='vertical')
plt.title('CPU wise price')
sns.set(rc={'figure.figsize':(5,5)})
plt.show()

# %%
#drop cpu and cpu name
df.drop(columns=['Cpu','Cpu Name'],inplace=True)
df.sample(5)
# Out:
#      Company     TypeName  Ram     Memory                    Gpu       OpSys  \
# 176     Acer     Notebook    4  128GB SSD  Intel HD Graphics 520  Windows 10
# 1281    Dell     Notebook    8    1TB HDD     AMD Radeon R5 M430       Linux
# 433   Lenovo  Workstation   16  512GB SSD   Nvidia GeForce 940MX  Windows 10
# 214   Huawei    Ultrabook    8  512GB SSD  Intel HD Graphics 620  Windows 10
# 1201  Lenovo     Notebook    8  500GB HDD   Nvidia GeForce 920MX       No OS
#
#       Weight        Price  Touchscreen  Ips         ppi     Cpu Branch
# 176     2.10   23922.7200            0    0  100.454670  Intel Core i3
# 1281    2.30   42943.1472            0    0  100.454670  Intel Core i7
# 433     2.30  130269.6000            0    1  282.423996  Intel Core i7
# 214     1.05   79866.7200            0    1  199.692071  Intel Core i7
# 1201    2.20   33513.1200            0    0  100.454670  Intel Core i7

# %% [markdown]
# WORK WITH RAM

# %%
#RAM
sns.countplot(x='Ram',data=df,palette='PiYG')
plt.xticks(rotation='vertical')
plt.title('RAM wise laptop')
sns.set(rc={'figure.figsize':(7,7)})
plt.show()

sns.barplot(x='Ram',y='Price',data=df,palette='PiYG')
plt.xticks(rotation='vertical')
plt.title('RAM wise price')
sns.set(rc={'figure.figsize':(7,7)})
plt.show()

# %% [markdown]
# WORK WITH MEMORY

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  256GB SSD             1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 32GB HDD                           1
# 64GB SSD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: Memory, dtype: int64

# %%
#Split the memory based on SSD,HDD,TB, Hybrid and Flash Storage
df['Memory']=df['Memory'].astype(str).replace('\.0','',regex=True)
df['Memory']=df['Memory'].str.replace('GB','')
df['Memory']=df['Memory'].str.replace('TB','000')
new=df['Memory'].str.split('+',n=1,expand=True)
#n=1 mean that only one split perform, the splitting occurs at the first occurence of the '+' character
#expand=True : When expand=True, the split element are returned as separate columns.In this case, there will be two columns, one for those before
#the + and one for those after the +

df['first']=new[0]
df['first']=df['first'].str.strip()


df['Layer1HDD']=df['first'].apply(lambda x:1 if 'HDD' in x else 0)
df['Layer1SSD']=df['first'].apply(lambda x:1 if 'SSD' in x else 0)
df['Layer1Hybrid']=df['first'].apply(lambda x:1 if 'Hybrid' in x else 0)
df['Layer1FlashStorage']=df['first'].apply(lambda x:1 if 'Flash Storage' in x else 0)

df['first']=df['first'].str.replace(r'\D','',regex=True)
#used to remove all non-digit characters from the values in the "first" column, where \D is for non-digit character



df['second']=new[1]
df['second']=df['second'].fillna('0')
df['second']=df['second'].str.strip()
#This is to make all None or missing value to be 0
df['Layer2HDD']=df['second'].apply(lambda x:1 if 'HDD' in x else 0)
df['Layer2SSD']=df['second'].apply(lambda x:1 if 'SSD' in x else 0)
df['Layer2Hybrid']=df['second'].apply(lambda x:1 if 'Hybrid' in x else 0)
df['Layer2FlashStorage']=df['second'].apply(lambda x:1 if 'Flash Storage' in x else 0)

df['second']=df['second'].str.replace(r'\D','',regex=True)




df['first']=df['first'].astype(int)
df['second']=df['second'].astype(int)
df['HDD']=df['first']*df['Layer1HDD']+df['second']*df['Layer2HDD']
df['SSD']=df['first']*df['Layer1SSD']+df['second']*df['Layer2SSD']
df['Hybrid']=df['first']*df['Layer1Hybrid']+df['second']*df['Layer2Hybrid']
df['FlashStorage']=df['first']*df['Layer1FlashStorage']+df['second']*df['Layer2FlashStorage']


df.drop(columns=['first','second','Layer1SSD','Layer1HDD','Layer1Hybrid','Layer1FlashStorage',
                 'Layer2SSD','Layer2HDD','Layer2Hybrid','Layer2FlashStorage'],inplace=True)
df.sample(5)
# Out:
#      Company   TypeName  Ram               Memory                      Gpu  \
# 110     Asus  Ultrabook   16  256 SSD +  1000 HDD     Nvidia GeForce MX150
# 668  Toshiba   Notebook    8              256 SSD    Intel HD Graphics 620
# 813     Dell   Notebook    8             1000 HDD  Nvidia GeForce GT 940MX
# 911       HP  Ultrabook    8              240 SSD    Intel HD Graphics 515
# 890       HP   Notebook    4              128 SSD    Intel HD Graphics 620
#
#           OpSys  Weight      Price  Touchscreen  Ips         ppi  \
# 110  Windows 10    1.50   67239.36            0    0  141.211998
# 668  Windows 10    2.00   67026.24            0    1  141.211998
# 813  Windows 10    1.98   51202.08            0    0  141.211998
# 911  Windows 10    1.09  165168.00            1    0  352.465147
# 890  Windows 10    1.95   67399.20            0    0  157.350512
#
#                 Cpu Branch   HDD  SSD  Hybrid  FlashStorage
# 110          Intel Core i7  1000  256       0             0
# 668          Intel Core i5     0  256       0             0
# 813          Intel Core i7  1000    0       0             0
# 911  Other Intel Processor     0  240       0             0
# 890          Intel Core i5     0  128       0             0

# %%
plt.figure(figsize=(16,6))
colormap=sns.color_palette('PiYG')
sns.heatmap(df.corr(),annot=True,cmap=colormap).set_title('Correlation Heatmap')
plt.show()
# Out:
# C:\Users\MinhHoang\AppData\Local\Temp\ipykernel_3432\1824497703.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap=colormap).set_title('Correlation Heatmap')

# %%
#since the Memory is no more needed, and Hybrid and Flash Storage have small correlation, so we will drop these 3 columns.
df.drop(columns=['Memory','Hybrid','FlashStorage'],inplace=True)
df.sample(3)
# Out:
#      Company   TypeName  Ram                      Gpu       OpSys  Weight  \
# 301     Asus     Gaming   16  Nvidia GeForce GTX 1070  Windows 10    2.90
# 1188    Dell  Ultrabook    8    Intel HD Graphics 520       Linux    1.23
# 436       HP   Notebook    4    Intel HD Graphics 400  Windows 10    2.10
#
#           Price  Touchscreen  Ips         ppi             Cpu Branch   HDD  \
# 301   113060.16            0    0  127.335675          Intel Core i7  1000
# 1188   58554.72            1    0  276.053530          Intel Core i5     0
# 436    18488.16            0    0  100.454670  Other Intel Processor   500
#
#       SSD
# 301   256
# 1188  256
# 436     0

# %% [markdown]
# WORK WITH GPU

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
df['GPU Branch']=df['Gpu'].apply(lambda x:x.split()[0])
df.sample(3)
# Out:
#     Company   TypeName  Ram                       Gpu       OpSys  Weight  \
# 49     Asus   Notebook    4      Nvidia GeForce 920MX  Windows 10    2.80
# 86       HP  Ultrabook    8  Nvidia GeForce GTX 940MX  Windows 10    1.83
# 415    Dell   Notebook    4        AMD Radeon R5 M430       Linux    2.30
#
#          Price  Touchscreen  Ips         ppi             Cpu Branch   HDD  \
# 49   24828.480            0    0   90.583402  Other Intel Processor  1000
# 86   37242.720            0    1  141.211998          Intel Core i7     0
# 415  31909.392            0    0  141.211998          Intel Core i5     0
#
#      SSD GPU Branch
# 49     0     Nvidia
# 86   256     Nvidia
# 415  256        AMD

# %%
df.drop(columns=['Gpu'],inplace=True)

# %%
df['GPU Branch'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: GPU Branch, dtype: int64

# %%
#Since the ARM is only 1, we drop ARM GPU
df=df[df['GPU Branch']!='ARM']

# %%
sns.barplot(x='GPU Branch',y='Price',data=df,palette='PiYG')
plt.xticks(rotation='vertical')
sns.set(rc={'figure.figsize':(5,5)})
plt.title('GPU branch wise Price')
plt.show()

# %% [markdown]
# #Work with Ops

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x='OpSys',y='Price',data=df,palette='PiYG')
plt.xticks(rotation='vertical')
plt.title('Operating System wise Price')
sns.set(rc={'figure.figsize':(8,8)})
plt.show()

# %%
def determine_os(inp):
    if inp=='Windows 10' or inp=='Windows 7' or inp=='Windows 10 S':
        return 'Windows'
    elif inp=='macOS' or inp=='Mac OS X':
        return 'Mac'
    else:
        return 'Others'

# %%
df['os']=df['OpSys'].apply(determine_os)
df.sample(5)
# Out:
#       Company            TypeName  Ram       OpSys  Weight      Price  \
# 135        HP            Notebook    8  Windows 10    1.63   52640.64
# 444        HP              Gaming    8  Windows 10    2.20   58554.72
# 1022       HP            Notebook    8  Windows 10    1.11   61218.72
# 1149   Lenovo  2 in 1 Convertible    8  Windows 10    1.27  124621.92
# 274   Toshiba            Notebook    8  Windows 10    2.20   43263.36
#
#       Touchscreen  Ips         ppi     Cpu Branch   HDD  SSD GPU Branch  \
# 135             0    0  157.350512  Intel Core i7     0  256      Intel
# 444             0    1  141.211998  Intel Core i7  1000  128     Nvidia
# 1022            0    1  165.632118  Intel Core i5     0  256      Intel
# 1149            1    1  209.800683  Intel Core i7     0  256      Intel
# 274             0    0  100.454670  Intel Core i7   500    0     Nvidia
#
#            os
# 135   Windows
# 444   Windows
# 1022  Windows
# 1149  Windows
# 274   Windows

# %%
sns.barplot(x='os',y='Price',data=df,palette='PiYG')
plt.xticks(rotation='vertical')
sns.set(rc={'figure.figsize':(8,8)})
plt.title('OS wise Price')
plt.show()

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
df.sample(3)
# Out:
#     Company  TypeName  Ram  Weight       Price  Touchscreen  Ips         ppi  \
# 940      HP    Gaming    8    2.75  74538.7200            0    1  127.335675
# 66       HP  Notebook    4    1.86  23373.4032            0    0  100.454670
# 42     Asus  Notebook    8    2.30  27864.9072            0    0  100.454670
#
#         Cpu Branch   HDD  SSD GPU Branch       os
# 940  Intel Core i5  1000  128     Nvidia  Windows
# 66   Intel Core i3   500    0        AMD  Windows
# 42   Intel Core i5  1000    0     Nvidia   Others

# %% [markdown]
# WORK WITH WEIGHT

# %%
#----------Distplot----------

sns.distplot(df['Weight'],hist_kws={'color':'purple', 'edgecolor':'black','linewidth':.5, 'linestyle':'-'})
sns.set(rc={'figure.figsize':(6,6)})
plt.title('Price Distribution')
plt.show()
# Out:
# C:\Users\MinhHoang\AppData\Local\Temp\ipykernel_3432\4178596259.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'],hist_kws={'color':'purple', 'edgecolor':'black','linewidth':.5, 'linestyle':'-'})

# %%
#Scatter plot
sns.scatterplot(x='Weight',y='Price',hue='Price',marker='+',data=df)
plt.title('Weight with Price')
sns.set(rc={'figure.figsize':(6,6)})
plt.show()

# %%
#Corr on the weight
plt.figure(figsize=(16,6))
colormap=sns.color_palette('PiYG')
sns.heatmap(df.corr(),annot=True,cmap=colormap).set_title('Correlation heat map')
plt.show()
# Out:
# C:\Users\MinhHoang\AppData\Local\Temp\ipykernel_3432\4203750591.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap=colormap).set_title('Correlation heat map')

# %% [markdown]
# WORK WITH PRICE

# %%
sns.distplot(np.log(df['Price']),hist_kws={'color':'purple', 'edgecolor':'black',
                       'linewidth':.5, 'linestyle':'-'})
sns.set(rc={"figure.figsize":(7, 5)})
plt.title("Price Distriution") #It's normal distribution
plt.show()
# Out:
# C:\Users\MinhHoang\AppData\Local\Temp\ipykernel_3432\3673733752.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']),hist_kws={'color':'purple', 'edgecolor':'black',

# %% [markdown]
# MODEL BUILDING
