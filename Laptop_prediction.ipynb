# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
image = mpimg.imread('Laptop.png')
plt.imshow(image)
plt.axis('off')  # Tắt hiển thị trục
plt.show()

# %%
#Import libraries and dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df=pd.read_csv('laptop_data.csv')
df.head(5)
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %% [markdown]
# BASIC UNDERSTANDING FOR DATA

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
#Drop unrequired column
df.drop(columns='Unnamed: 0',inplace=True)
df.head(5)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
#NOW SPLIT the mixed variables
df['Ram'] = df['Ram'].str.replace('GB','')

#Weight---
df['Weight'] = df['Weight'].str.replace('kg','')

#Change data type----
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')
df.sample(5)
# Out:
#      Company   TypeName  Inches                 ScreenResolution  \
# 430  Samsung    Netbook    11.6                         1366x768
# 116       HP   Notebook    14.0                Full HD 1920x1080
# 698  Toshiba  Ultrabook    13.3  Full HD / Touchscreen 1920x1080
# 751       HP   Notebook    15.6                Full HD 1920x1080
# 493     Acer   Notebook    15.6                         1366x768
#
#                                       Cpu  Ram              Memory  \
# 430  Intel Celeron Dual Core N3060 1.6GHz    4  16GB Flash Storage
# 116            Intel Core i7 8550U 1.8GHz    8           512GB SSD
# 698            Intel Core i7 6500U 2.5GHz   16           512GB SSD
# 751            Intel Core i5 6300U 2.4GHz    8           256GB SSD
# 493           AMD A10-Series 9620P 2.5GHz    8             1TB HDD
#
#                         Gpu       OpSys  Weight      Price
# 430   Intel HD Graphics 400   Chrome OS    1.15   14332.32
# 116  Intel UHD Graphics 620  Windows 10    1.63   57755.52
# 698   Intel HD Graphics 520  Windows 10    1.36  100006.56
# 751   Intel HD Graphics 520  Windows 10    1.84  101232.00
# 493       AMD Radeon RX 540  Windows 10    2.20   30849.12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %% [markdown]
# #EDA with Data

# %% [markdown]
# 1.Price distribution

# %%
sns.distplot(df['Price'],hist_kws={'color':'green','edgecolor':'black','linewidth':.5,'linestyle':'-'})
sns.set(rc={'figure.figsize':(7,5)})
plt.title('Price distribution')
plt.show()
# Out:
# C:\Users\MinhHoang\AppData\Local\Temp\ipykernel_21024\304912976.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'],hist_kws={'color':'green','edgecolor':'black','linewidth':.5,'linestyle':'-'})

# %% [markdown]
# 2.Company

# %%
#Company wise laptop------
sns.countplot(x='Company',data=df,palette='PiYG')
plt.xticks(rotation='vertical')
plt.title("Company wise laptop")
sns.set(rc={"figure.figsize":(8, 8)})
plt.show()

#Company with Price------
sns.barplot(x='Company',y='Price',data=df,palette='PiYG')
plt.xticks(rotation='vertical')
sns.set(rc={'figure.figsize':(7,7)})
plt.title('Company wise Price')
plt.show()

# %% [markdown]
# 3.TypeName

# %%
#Type name wise laptops-----
sns.countplot(x="TypeName",data=df,palette='PiYG')
plt.xticks(rotation='vertical')
plt.title("TypeName wise laptops")
sns.set(rc={'figure.figsize':(8,8)})
plt.show()

#TypeName wise Price--------
sns.barplot(x='TypeName',y='Price',data=df,palette='PiYG')
plt.xticks(rotation='vertical')
plt.title("TypeName wise Price")
sns.set(rc={'figure.figsize':(7,7)})
plt.show()

# %% [markdown]
# 4.Inches

# %%
#Distplot 
sns.distplot(df['Inches'],hist_kws={'color':'red','edgecolor':'black','linewidth':.5,
                                   'linestyle':'--'})
sns.set(rc={'figure.figsize':(7,5)})
plt.title('Inches')
plt.show()

#Scatter plot------
sns.scatterplot(x='Inches',y='Price',hue='Inches',marker='+',data=df)
plt.title('Inches with price')
sns.set(rc={'figure.figsize':(8,8)})
plt.show()
# Out:
# C:\Users\MinhHoang\AppData\Local\Temp\ipykernel_21024\3358653546.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Inches'],hist_kws={'color':'red','edgecolor':'black','linewidth':.5,

# %% [markdown]
# 5. Work with screen resolution

# %%
print(df['ScreenResolution'].value_counts())
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ 2560x1440                       3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# Touchscreen 2400x1600                              3
# 2560x1440                                          3
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 1920x1200                        1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: ScreenResolution, dtype: int64

# %%
#Split the column based on Touchscreen
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)
df['Ips'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)
df.sample(10)
# Out:
#      Company            TypeName  Inches  \
# 69      Asus              Gaming    17.3
# 1058    Dell  2 in 1 Convertible    13.3
# 569   Lenovo            Notebook    14.0
# 953     Asus  2 in 1 Convertible    12.5
# 538       HP              Gaming    17.3
# 295   Lenovo              Gaming    15.6
# 1278    Dell            Notebook    15.6
# 1090    Dell            Notebook    15.6
# 280   Lenovo            Notebook    17.3
# 805       HP             Netbook    12.5
#
#                                ScreenResolution  \
# 69                            Full HD 1920x1080
# 1058  IPS Panel Full HD / Touchscreen 1920x1080
# 569                                    1366x768
# 953                           Full HD 1920x1080
# 538                           Full HD 1920x1080
# 295                 IPS Panel Full HD 1920x1080
# 1278                                   1366x768
# 1090                                   1366x768
# 280                                    1600x900
# 805                                    1366x768
#
#                                        Cpu  Ram                Memory  \
# 69             Intel Core i7 7700HQ 2.8GHz   12               1TB HDD
# 1058            Intel Core i7 7500U 2.7GHz   12             256GB SSD
# 569             Intel Core i5 7200U 2.5GHz    4             500GB HDD
# 953            Intel Core M M7-6Y75 1.2GHz    8    64GB Flash Storage
# 538            Intel Core i7 7700HQ 2.8GHz   12               1TB HDD
# 295            Intel Core i7 7700HQ 2.8GHz    8               1TB HDD
# 1278  Intel Celeron Dual Core N3050 1.6GHz    2             500GB HDD
# 1090  Intel Pentium Quad Core N3700 1.6GHz    4             500GB HDD
# 280             Intel Core i7 7500U 2.7GHz    6  128GB SSD +  1TB HDD
# 805             Intel Core i5 7300U 2.6GHz    8             256GB SSD
#
#                              Gpu       OpSys  Weight       Price  Touchscreen  \
# 69    Nvidia GeForce GTX 1050 Ti       Linux    3.00  50562.7200            0
# 1058       Intel HD Graphics 620  Windows 10    1.60  69210.7200            1
# 569        Intel HD Graphics 620  Windows 10    2.02  52747.2000            0
# 953        Intel HD Graphics 515   Chrome OS    1.20  61751.5200            0
# 538      Nvidia GeForce GTX 1060  Windows 10    2.62  95850.7200            0
# 295      Nvidia GeForce GTX 1060  Windows 10    3.20  69210.7200            0
# 1278           Intel HD Graphics  Windows 10    2.20  20193.1200            0
# 1090           Intel HD Graphics       Linux    2.20  20965.1472            0
# 280         Nvidia GeForce 940MX  Windows 10    2.80  45767.5200            0
# 805        Intel HD Graphics 620  Windows 10    1.26  74005.9200            0
#
#       Ips
# 69      0
# 1058    1
# 569     0
# 953     0
# 538     0
# 295     1
# 1278    0
# 1090    0
# 280     0
# 805     0

# %%
#Touchscreen
sns.countplot(x="Touchscreen",data=df,palette='PiYG')
plt.title('Count Touchscreen')
plt.xticks(rotation='vertical')
sns.set(rc={'figure.figsize':(5,5)})
plt.show()

sns.barplot(x='Touchscreen',y='Price',data=df,palette='PiYG')
plt.title('TouchScreen with Price')
plt.xticks(rotation='vertical')
sns.set(rc={'figure.figsize':(5,5)})
plt.show()

# %%
#IPs
sns.countplot(x='Ips',data=df,palette='PiYG')
plt.xticks(rotation='vertical')
plt.title('Count IPs')
sns.set(rc={'figure.figsize':(5,5)})
plt.show()

#TypeName with Price
sns.barplot(x='Ips',y='Price',data=df,palette='PiYG')
plt.xticks(rotation='vertical')
sns.set(rc={'figure.figsize':(5,5)})
plt.title('IPs with Price')
plt.show()

# %%
new=df['ScreenResolution'].str.split('x',n=1,expand=True)
#Again split the screen resolution
df['X_res']=new[0]
df['Y-res']=new[1]
df.sample(5)
# Out:
#     Company     TypeName  Inches   ScreenResolution  \
# 732      HP     Notebook    15.6  Full HD 1920x1080
# 261  Lenovo     Notebook    15.6  Full HD 1920x1080
# 278  Lenovo     Notebook    17.3           1600x900
# 46   Lenovo     Notebook    15.6           1366x768
# 692      HP  Workstation    17.3  Full HD 1920x1080
#
#                              Cpu  Ram                Memory  \
# 732   AMD A9-Series A9-9420 3GHz    6  128GB SSD +  1TB HDD
# 261     Intel Core i3 6006U 2GHz    4             256GB SSD
# 278     Intel Core i3 6006U 2GHz    4               1TB HDD
# 46      Intel Core i3 6006U 2GHz    4             128GB SSD
# 692  Intel Core i7 7700HQ 2.8GHz    8             500GB HDD
#
#                        Gpu       OpSys  Weight        Price  Touchscreen  Ips  \
# 732         AMD Radeon 520  Windows 10    2.10   34632.0000            0    0
# 261  Intel HD Graphics 520       No OS    2.20   23656.3200            0    0
# 278  Intel HD Graphics 520  Windows 10    2.80   26053.9200            0    0
# 46   Intel HD Graphics 520       No OS    2.20   19660.3200            0    0
# 692    Nvidia Quadro M1200  Windows 10    3.14  101657.7072            0    0
#
#             X_res Y-res
# 732  Full HD 1920  1080
# 261  Full HD 1920  1080
# 278          1600   900
# 46           1366   768
# 692  Full HD 1920  1080

# %%
#Edit X-res
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])
df.sample(5)
# Out:
#      Company  TypeName  Inches             ScreenResolution  \
# 841     Dell    Gaming    17.3  IPS Panel Full HD 1920x1080
# 434   Lenovo  Notebook    15.6            Full HD 1920x1080
# 1012      HP  Notebook    14.0            Full HD 1920x1080
# 716     Dell  Notebook    15.6            Full HD 1920x1080
# 138   Lenovo  Notebook    15.6            Full HD 1920x1080
#
#                               Cpu  Ram                Memory  \
# 841   Intel Core i7 7700HQ 2.8GHz   32  512GB SSD +  1TB HDD
# 434   Intel Core i7 7820HQ 2.9GHz   16             512GB SSD
# 1012   Intel Core i5 7200U 2.5GHz    4             256GB SSD
# 716    Intel Core i5 7300U 2.6GHz    8             256GB SSD
# 138    Intel Core i5 7200U 2.5GHz    4               1TB HDD
#
#                           Gpu       OpSys  Weight        Price  Touchscreen  \
# 841   Nvidia GeForce GTX 1070  Windows 10    4.42  163723.5792            0
# 434      Nvidia Quadro M2200M  Windows 10    2.50  130482.7200            0
# 1012    Intel HD Graphics 620  Windows 10    1.48   84715.2000            0
# 716     Intel HD Graphics 620  Windows 10    1.90   62817.1200            0
# 138      Nvidia GeForce 920MX       No OS    2.20   26586.7200            0
#
#       Ips X_res Y-res
# 841     1  1920  1080
# 434     0  1920  1080
# 1012    0  1920  1080
# 716     0  1920  1080
# 138     0  1920  1080

# %%
#Change datatype
df['X_res']=df['X_res'].astype('int')
df['Y-res']=df['Y-res'].astype('int')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y-res             1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# memory usage: 132.5+ KB

# %% [markdown]
# #WORK WITH PRICE

# %%
df.corr()['Price']
# Out:
# C:\Users\MinhHoang\AppData\Local\Temp\ipykernel_21024\815546952.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price']
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# X_res          0.556529
# Y-res          0.552809
# Name: Price, dtype: float64

# %%
df['ppi']=((df['X_res']**2+df['Y-res']**2)**0.5/df['Inches']).astype(float)
df.corr()['Price']
# Out:
# C:\Users\MinhHoang\AppData\Local\Temp\ipykernel_21024\3000508125.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price']
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# X_res          0.556529
# Y-res          0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %%
df.sample(5)
# Out:
#      Company   TypeName  Inches  \
# 1193   Apple  Ultrabook    12.0
# 951     Dell  Ultrabook    14.0
# 163   Lenovo     Gaming    15.6
# 816    Razer  Ultrabook    12.5
# 947   Lenovo   Notebook    15.6
#
#                                    ScreenResolution  \
# 1193             IPS Panel Retina Display 2304x1440
# 951                               Full HD 1920x1080
# 163                     IPS Panel Full HD 1920x1080
# 816   IPS Panel 4K Ultra HD / Touchscreen 3840x2160
# 947                               Full HD 1920x1080
#
#                               Cpu  Ram               Memory  \
# 1193          Intel Core M 1.1GHz    8  256GB Flash Storage
# 951    Intel Core i7 7600U 2.8GHz    8            256GB SSD
# 163   Intel Core i7 7700HQ 2.8GHz   16            256GB SSD
# 816    Intel Core i7 7500U 2.5GHz   16            512GB SSD
# 947    Intel Core i7 7500U 2.7GHz    8              1TB HDD
#
#                              Gpu       OpSys  Weight     Price  Touchscreen  \
# 1193      Intel HD Graphics 5300    Mac OS X    0.92  61964.64            0
# 951        Intel HD Graphics 620  Windows 10    1.36  94572.00            0
# 163   Nvidia GeForce GTX 1050 Ti  Windows 10    2.50  57489.12            0
# 816        Intel HD Graphics 620  Windows 10    1.29  95850.72            1
# 947         Nvidia GeForce 920MX       No OS    2.20  36496.80            0
#
#       Ips  X_res  Y-res         ppi
# 1193    1   2304   1440  226.415547
# 951     0   1920   1080  157.350512
# 163     1   1920   1080  141.211998
# 816     1   3840   2160  352.465147
# 947     0   1920   1080  141.211998

# %%
df.drop(columns=['ScreenResolution','Inches','X_res','Y-res'],inplace=True)
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi
# 0  226.983005
# 1  127.677940
# 2  141.211998
# 3  220.534624
# 4  226.983005

# %% [markdown]
# WORK WITH CPU

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
#Split first 3 words
df['Cpu Name']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))
df.sample(5)
# Out:
#       Company  TypeName                         Cpu  Ram     Memory  \
# 934   Toshiba  Notebook  Intel Core i5 6200U 2.3GHz    4  128GB SSD
# 1205     Dell  Notebook  Intel Core i5 7200U 2.5GHz    8  256GB SSD
# 633    Lenovo  Notebook    Intel Core i3 6006U 2GHz    4    1TB HDD
# 415      Dell  Notebook  Intel Core i5 7200U 2.5GHz    4  256GB SSD
# 1134     Acer  Notebook  Intel Core i5 7200U 2.5GHz    4    1TB HDD
#
#                         Gpu       OpSys  Weight      Price  Touchscreen  Ips  \
# 934   Intel HD Graphics 520  Windows 10    1.47  58874.400            0    1
# 1205     AMD Radeon R7 M445  Windows 10    2.36  47365.920            0    0
# 633   Nvidia GeForce 920MX   Windows 10    2.20  30849.120            0    0
# 415      AMD Radeon R5 M430       Linux    2.30  31909.392            0    0
# 1134   Nvidia GeForce 940MX  Windows 10    2.23  32820.480            0    0
#
#              ppi       Cpu Name
# 934   157.350512  Intel Core i5
# 1205  141.211998  Intel Core i5
# 633   141.211998  Intel Core i3
# 415   141.211998  Intel Core i5
# 1134  141.211998  Intel Core i5

# %%
#CPU name extration function
def fetch_processor(text):
    if text=='Intel Core i7' or text=='Intel Core i5' or text=='Intel Core i3':
        return text
    else:
        if text.split()[0]=='Intel':
            return 'Other Intel Processor'
        else: 
            return 'AMD processor'

df['Cpu Branch']=df['Cpu Name'].apply(fetch_processor)
df.sample(5)
# Out:
#      Company            TypeName                                   Cpu  Ram  \
# 3      Apple           Ultrabook                  Intel Core i7 2.7GHz   16
# 1167  Lenovo            Notebook              Intel Core i3 6006U 2GHz    4
# 455     Dell  2 in 1 Convertible  Intel Pentium Quad Core N3710 1.6GHz    4
# 1234   Apple           Ultrabook                  Intel Core i5 1.6GHz    4
# 1182    Dell            Notebook            Intel Core i7 7500U 2.7GHz    8
#
#                    Memory                      Gpu       OpSys  Weight  \
# 3               512GB SSD       AMD Radeon Pro 455       macOS    1.83
# 1167              1TB HDD    Nvidia GeForce 920MX   Windows 10    2.20
# 455             500GB HDD    Intel HD Graphics 405  Windows 10    1.47
# 1234  256GB Flash Storage   Intel HD Graphics 6000    Mac OS X    1.08
# 1182            256GB SSD  Nvidia GeForce GT 940MX       Linux    1.98
#
#             Price  Touchscreen  Ips         ppi            Cpu Name  \
# 3     135195.3360            0    1  220.534624       Intel Core i7
# 1167   24935.0400            0    0  141.211998       Intel Core i3
# 455    25521.1200            1    0  135.094211  Intel Pentium Quad
# 1234   51095.5200            0    0  135.094211       Intel Core i5
# 1182   47686.1328            0    0  141.211998       Intel Core i7
#
#                  Cpu Branch
# 3             Intel Core i7
# 1167          Intel Core i3
# 455   Other Intel Processor
# 1234          Intel Core i5
# 1182          Intel Core i7

# %%
#CPU branch
sns.countplot(x='Cpu Branch',data=df,palette='PiYG')
plt.xticks(rotation='vertical')
plt.title('CPU wise laptop')
sns.set(rc={'figure.figsize':(5,5)})
plt.show()


#CPU Branch wise price
sns.barplot(x='Cpu Branch',y='Price',data=df,palette='PiYG')
plt.xticks(rotation='vertical')
plt.title('CPU wise price')
sns.set(rc={'figure.figsize':(5,5)})
plt.show()

# %%
#drop cpu and cpu name
df.drop(columns=['Cpu','Cpu Name'],inplace=True)
df.sample(5)
# Out:
#      Company            TypeName  Ram                Memory  \
# 58       MSI              Gaming   16  256GB SSD +  2TB HDD
# 401     Asus              Gaming   16  256GB SSD +  1TB HDD
# 461     Acer             Netbook    4             128GB SSD
# 970     Dell  2 in 1 Convertible   16             512GB SSD
# 1032     MSI              Gaming    8  128GB SSD +  1TB HDD
#
#                           Gpu       OpSys  Weight       Price  Touchscreen  \
# 58    Nvidia GeForce GTX 1070  Windows 10    2.43  130482.720            0
# 401   Nvidia GeForce GTX 1050  Windows 10    2.90   81465.120            0
# 461     Intel HD Graphics 400  Windows 10    1.40   23176.800            0
# 970     Intel HD Graphics 615  Windows 10    1.22  101178.720            1
# 1032  Nvidia GeForce GTX 1050  Windows 10    2.70   63499.104            0
#
#       Ips         ppi             Cpu Branch
# 58      0  127.335675          Intel Core i7
# 401     0  127.335675          Intel Core i7
# 461     0  135.094211  Other Intel Processor
# 970     0  276.053530          Intel Core i7
# 1032    0  127.335675          Intel Core i7

# %% [markdown]
# WORK WITH RAM

# %%
#RAM
sns.countplot(x='Ram',data=df,palette='PiYG')
plt.xticks(rotation='vertical')
plt.title('RAM wise laptop')
sns.set(rc={'figure.figsize':(7,7)})
plt.show()

sns.barplot(x='Ram',y='Price',data=df,palette='PiYG')
plt.xticks(rotation='vertical')
plt.title('RAM wise price')
sns.set(rc={'figure.figsize':(7,7)})
plt.show()

# %% [markdown]
# WORK WITH MEMORY

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  256GB SSD             1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 32GB HDD                           1
# 64GB SSD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: Memory, dtype: int64

# %%
#Split the memory based on SSD,HDD,TB, Hybrid and Flash Storage
df['Memory']=df['Memory'].astype(str).replace('\.0','',regex=True)
df['Memory']=df['Memory'].str.replace('GB','')
df['Memory']=df['Memory'].str.replace('TB','000')
new=df['Memory'].str.split('+',n=1,expand=True)
#n=1 mean that only one split perform, the splitting occurs at the first occurence of the '+' character
#expand=True : When expand=True, the split element are returned as separate columns.In this case, there will be two columns, one for those before
#the + and one for those after the +

df['first']=new[0]
df['first']=df['first'].str.strip()


df['Layer1HDD']=df['first'].apply(lambda x:1 if 'HDD' in x else 0)
df['Layer1SSD']=df['first'].apply(lambda x:1 if 'SSD' in x else 0)
df['Layer1Hybrid']=df['first'].apply(lambda x:1 if 'Hybrid' in x else 0)
df['Layer1FlashStorage']=df['first'].apply(lambda x:1 if 'Flash Storage' in x else 0)

df['first']=df['first'].str.replace(r'\D','',regex=True)
#used to remove all non-digit characters from the values in the "first" column, where \D is for non-digit character



df['second']=new[1]
df['second']=df['second'].fillna('0')
df['second']=df['second'].str.strip()
#This is to make all None or missing value to be 0
df['Layer2HDD']=df['second'].apply(lambda x:1 if 'HDD' in x else 0)
df['Layer2SSD']=df['second'].apply(lambda x:1 if 'SSD' in x else 0)
df['Layer2Hybrid']=df['second'].apply(lambda x:1 if 'Hybrid' in x else 0)
df['Layer2FlashStorage']=df['second'].apply(lambda x:1 if 'Flash Storage' in x else 0)

df['second']=df['second'].str.replace(r'\D','',regex=True)




df['first']=df['first'].astype(int)
df['second']=df['second'].astype(int)
df['HDD']=df['first']*df['Layer1HDD']+df['second']*df['Layer2HDD']
df['SSD']=df['first']*df['Layer1SSD']+df['second']*df['Layer2SSD']
df['Hybrid']=df['first']*df['Layer1Hybrid']+df['second']*df['Layer2Hybrid']
df['FlashStorage']=df['first']*df['Layer1FlashStorage']+df['second']*df['Layer2FlashStorage']


df.drop(columns=['first','second','Layer1SSD','Layer1HDD','Layer1Hybrid','Layer1FlashStorage',
                 'Layer2SSD','Layer2HDD','Layer2Hybrid','Layer2FlashStorage'],inplace=True)
df.sample(5)
# Out:
#      Company            TypeName  Ram               Memory  \
# 1138     MSI              Gaming   16  256 SSD +  1000 HDD
# 1107  Lenovo  2 in 1 Convertible    4              256 SSD
# 451     Dell         Workstation   16              256 SSD
# 717   Lenovo            Notebook    4              500 HDD
# 1133      HP           Ultrabook    8              256 SSD
#
#                           Gpu       OpSys  Weight      Price  Touchscreen  \
# 1138  Nvidia GeForce GTX 980M  Windows 10    3.78  127818.72            0
# 1107    Intel HD Graphics 520  Windows 10    2.10   46193.76            1
# 451        Nvidia Quadro M620  Windows 10    2.17  105228.00            0
# 717             AMD Radeon R4  Windows 10    2.19   15877.44            0
# 1133    Intel HD Graphics 620  Windows 10    1.84   40066.56            0
#
#       Ips         ppi     Cpu Branch   HDD  SSD  Hybrid  FlashStorage
# 1138    0  127.335675  Intel Core i7  1000  256       0             0
# 1107    1  141.211998  Intel Core i5     0  256       0             0
# 451     1  141.211998  Intel Core i7     0  256       0             0
# 717     0  100.454670  AMD processor   500    0       0             0
# 1133    0  141.211998  Intel Core i7     0  256       0             0

# %%
plt.figure(figsize=(16,6))
colormap=sns.color_palette('PiYG')
sns.heatmap(df.corr(),annot=True,cmap=colormap).set_title('Correlation Heatmap')
plt.show()
# Out:
# C:\Users\MinhHoang\AppData\Local\Temp\ipykernel_21024\1824497703.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap=colormap).set_title('Correlation Heatmap')

# %%
#since the Memory is no more needed, and Hybrid and Flash Storage have small correlation, so we will drop these 3 columns.
df.drop(columns=['Memory','Hybrid','FlashStorage'],inplace=True)
df.sample(3)
# Out:
#      Company   TypeName  Ram                     Gpu       OpSys  Weight  \
# 1242    Acer   Notebook    4   Intel HD Graphics 520       Linux    2.40
# 33      Dell  Ultrabook   16  Intel UHD Graphics 620  Windows 10    1.20
# 1166  Lenovo   Notebook    8   Intel HD Graphics 620  Windows 10    1.95
#
#           Price  Touchscreen  Ips         ppi     Cpu Branch  HDD  SSD
# 1242  19276.704            0    0  100.454670  Intel Core i3  500    0
# 33    99580.320            1    0  276.053530  Intel Core i7    0  512
# 1166  74059.200            0    1  141.211998  Intel Core i5    0  256

# %% [markdown]
# WORK WITH GPU

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
df['GPU Branch']=df['Gpu'].apply(lambda x:x.split()[0])
df.sample(3)
# Out:
#       Company   TypeName  Ram                    Gpu       OpSys  Weight  \
# 963   Toshiba  Ultrabook    8  Intel HD Graphics 620  Windows 10    1.10
# 964        HP   Notebook    8   Nvidia GeForce 930MX  Windows 10    2.04
# 1074   Lenovo  Ultrabook    8  Intel HD Graphics 520  Windows 10    1.30
#
#            Price  Touchscreen  Ips         ppi     Cpu Branch   HDD  SSD  \
# 963   95371.2000            1    0  176.232574  Intel Core i7     0  512
# 964   45101.5200            0    0  100.454670  Intel Core i5  1000    0
# 1074  91294.7472            1    1  176.232574  Intel Core i7     0  256
#
#      GPU Branch
# 963       Intel
# 964      Nvidia
# 1074      Intel

# %%
df.drop(columns=['Gpu'],inplace=True)

# %%
df['GPU Branch'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: GPU Branch, dtype: int64

# %%
#Since the ARM is only 1, we drop ARM GPU
df=df[df['GPU Branch']!='ARM']

# %%
sns.barplot(x='GPU Branch',y='Price',data=df,palette='PiYG')
plt.xticks(rotation='vertical')
sns.set(rc={'figure.figsize':(5,5)})
plt.title('GPU branch wise Price')
plt.show()

# %% [markdown]
# #Work with Ops

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x='OpSys',y='Price',data=df,palette='PiYG')
plt.xticks(rotation='vertical')
plt.title('Operating System wise Price')
sns.set(rc={'figure.figsize':(8,8)})
plt.show()

# %%
def determine_os(inp):
    if inp=='Windows 10' or inp=='Windows 7' or inp=='Windows 10 S':
        return 'Windows'
    elif inp=='macOS' or inp=='Mac OS X':
        return 'Mac'
    else:
        return 'Others'

# %%
df['os']=df['OpSys'].apply(determine_os)
df.sample(5)
# Out:
#     Company            TypeName  Ram       OpSys  Weight        Price  \
# 971    Dell           Ultrabook    8  Windows 10    1.50  104587.5744
# 709      HP            Notebook    6  Windows 10    2.71   34898.9328
# 167    Dell              Gaming    8  Windows 10    2.56   56502.9072
# 44     Dell  2 in 1 Convertible   12  Windows 10    2.77   53226.7200
# 598    Dell  2 in 1 Convertible    8  Windows 10    1.34   88977.6000
#
#      Touchscreen  Ips         ppi     Cpu Branch   HDD  SSD GPU Branch  \
# 971            1    0  209.800683  Intel Core i7     0  256      Intel
# 709            0    1  127.335675  AMD processor  2000    0        AMD
# 167            0    0  141.211998  Intel Core i7  1000  128     Nvidia
# 44             1    0  127.335675  Intel Core i5  1000    0     Nvidia
# 598            1    0  176.232574  Intel Core i5     0  256      Intel
#
#           os
# 971  Windows
# 709  Windows
# 167  Windows
# 44   Windows
# 598  Windows

# %%
sns.barplot(x='os',y='Price',data=df,palette='PiYG')
plt.xticks(rotation='vertical')
sns.set(rc={'figure.figsize':(8,8)})
plt.title('OS wise Price')
plt.show()

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
df.sample(3)
# Out:
#      Company  TypeName  Ram  Weight        Price  Touchscreen  Ips  \
# 1104  Lenovo    Gaming   16     2.4   63882.7200            0    0
# 423     Asus  Notebook    8     2.3   31808.1600            0    0
# 738      MSI    Gaming   16     1.8  111593.8944            0    0
#
#              ppi     Cpu Branch   HDD  SSD GPU Branch       os
# 1104  141.211998  Intel Core i7     0  512     Nvidia  Windows
# 423   141.211998  Intel Core i3  1000    0     Nvidia   Others
# 738   141.211998  Intel Core i7  1000  256     Nvidia  Windows

# %% [markdown]
# WORK WITH WEIGHT

# %%
#----------Distplot----------

sns.distplot(df['Weight'],hist_kws={'color':'purple', 'edgecolor':'black','linewidth':.5, 'linestyle':'-'})
sns.set(rc={'figure.figsize':(6,6)})
plt.title('Price Distribution')
plt.show()
# Out:
# C:\Users\MinhHoang\AppData\Local\Temp\ipykernel_21024\4178596259.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'],hist_kws={'color':'purple', 'edgecolor':'black','linewidth':.5, 'linestyle':'-'})

# %%
#Scatter plot
sns.scatterplot(x='Weight',y='Price',hue='Price',marker='+',data=df)
plt.title('Weight with Price')
sns.set(rc={'figure.figsize':(6,6)})
plt.show()

# %%
#Corr on the weight
plt.figure(figsize=(16,6))
colormap=sns.color_palette('PiYG')
sns.heatmap(df.corr(),annot=True,cmap=colormap).set_title('Correlation heat map')
plt.show()
# Out:
# C:\Users\MinhHoang\AppData\Local\Temp\ipykernel_21024\4203750591.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap=colormap).set_title('Correlation heat map')

# %% [markdown]
# WORK WITH PRICE

# %%
sns.distplot(np.log(df['Price']),hist_kws={'color':'purple', 'edgecolor':'black',
                       'linewidth':.5, 'linestyle':'-'})
sns.set(rc={"figure.figsize":(7, 5)})
plt.title("Price Distriution") #It's normal distribution
plt.show()
# Out:
# C:\Users\MinhHoang\AppData\Local\Temp\ipykernel_21024\3673733752.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']),hist_kws={'color':'purple', 'edgecolor':'black',

# %% [markdown]
# MODEL BUILDING

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import r2_score, mean_absolute_error

# Create a ColumnTransformer for one-hot encoding the categorical features
encoder = ColumnTransformer(
    transformers=[('encoder', OneHotEncoder(sparse=False, drop='first'), [0, 1, 7, 10, 11])],
    remainder='passthrough'
)

# Fit and transform the training data
X_train_encoded = encoder.fit_transform(X_train)

# Transform the test data
X_test_encoded = encoder.transform(X_test)
# Out:
# d:\SETUP\lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# Create and fit the Linear Regression model
model = LinearRegression()
model.fit(X_train_encoded, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test_encoded)

# Calculate R2 score and mean absolute error
r2_score = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print('R2 score:', r2_score)
print('MAE:', mae)
# Out:
# R2 score: 0.8002405966123065
# MAE: 0.20453995815619525

# %% [markdown]
# Ridge Regression

# %%
#Create and fit the Ridge Regression
from sklearn.linear_model import Ridge
model=Ridge(alpha=10)
model.fit(X_train_encoded,y_train)
# Make predictions on the test data
y_pred = model.predict(X_test_encoded)

# Calculate R2 score and mean absolute error
r2score = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print('R2 score:', r2score)
print('MAE:', mae)
# Out:
# R2 score: 0.8025355126649508
# MAE: 0.20379724333815172

# %%
from sklearn.neighbors import KNeighborsRegressor
model=KNeighborsRegressor(n_neighbors=10)
model.fit(X_train_encoded,y_train)
# Make predictions on the test data
y_pred = model.predict(X_test_encoded)

# Calculate R2 score and mean absolute error
r2score = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print('R2 score:', r2score)
print('MAE:', mae)
# Out:
# R2 score: 0.7640747114662543
# MAE: 0.21763163252229878
